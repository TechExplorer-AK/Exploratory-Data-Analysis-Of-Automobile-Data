# %% [markdown]
# # **Project Name - EDA Automobile Data Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In the highly competitive automotive industry, understanding the variables that influence car prices is crucial for manufacturers, dealerships, and consumers. This project focuses on analyzing a comprehensive dataset of automobile attributes to uncover insights into what drives the pricing dynamics of cars in the market.
#
# **Dataset Overview**
#
#  The dataset contains a wealth of information about cars, encompassing technical specifications, performance metrics, and descriptive features. Key attributes include 'symboling' (insurance risk rating), 'normalized-losses', 'make' (manufacturer), 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', and 'price'.
#
# **Business Objective**
#
#  The primary objective of this project is to explore and analyze the factors influencing car prices. By leveraging data analysis and visualization techniques, our goal is to provide actionable insights that help stakeholders make informed decisions regarding pricing strategies, product development, and consumer trends.
#
# **Methodology**
#
#  To achieve our objective, we will employ a structured methodology:
#
# 1. **Exploratory Data Analysis (EDA):**
#
#   We will begin with exploratory data analysis to understand the dataset's characteristics. This involves summarizing the main statistics of numerical variables, identifying any missing values or outliers, and gaining insights into the distribution patterns of key features.
#
# 2. **Visualization Techniques:**
#
#    Utilizing various visualizations such as scatter plots, histograms, bar plots, and correlation matrices, we will explore relationships between variables and their impact on car prices.
#
#    Examples of visualizations include:
#   * **Average Price by Car Make:** Analyzing how prices vary across
#     different car manufacturers.
#
#   * **Scatter Plot of Horsepower vs. Price:** Examining the
#     relationship between engine power and car prices.
#
#   * **Bar Plot of Fuel Type vs. Average Price:** Comparing the
#     average prices of cars based on their fuel types.
#
#   * **3D Scatter Plot: Horsepower vs. MPG:** To visually explore and understand relationships between three variables (Horsepower, City MPG, and Highway MPG).
#
#   * **Correlation Heatmap:** Identifying correlations between
#     numerical variables to understand which factors most strongly influence pricing.
#
# 3. **Statistical Analysis:**
#
# * We will conduct statistical analyses to quantify relationships
#   and derive meaningful insights.
#
#   This includes calculating:
#
#   * **Average Prices:** Compute average prices for different car makes, body styles, and other categorical variables.
#
#   * **Correlation Coefficients:** Determine correlation strengths between attributes like horsepower, engine size, and price.
#
#   * **Price Distribution Analysis:** Analyze the distribution of car prices to understand price ranges and trends.
#
#
# 4. **Insights and Recommendations:**
#
#  Based on our data-driven analysis, we will derive actionable insights and recommendations. These insights will address key questions such as:
#   * Which car features contribute most to price variations?
#
#   * How do factors like fuel type, engine size, and body style impact pricing?
#
#   * What strategies can manufacturers and dealerships adopt to optimize pricing and enhance competitiveness in the market?
#
#
# **Expected Outcomes**
#
#   By the conclusion of this project, we aim to uncover significant factors influencing car prices. The insights gained will be valuable for stakeholders across the automotive industry:
#
#   * **Manufacturers:** Informing product development decisions and pricing strategies based on consumer preferences and market trends.
#
# * **Dealerships:** Setting competitive prices and understanding pricing dynamics to attract customers.
#
# * **Consumers:** Making informed purchasing decisions by understanding the value proposition of different car features and configurations.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/TechExplorer-AK/Exploratory-Data-Analysis-Of-Automobile-Data.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **BUSINESS PROBLEM OVERVIEW**
#
# Our objective is to explore and understand the factors that influence car prices using a dataset containing various automotive attributes. Through analysis and visualization, we aim to uncover key insights into what determines the pricing of cars in the market. This analysis will include calculating average prices by car make, examining correlations between numerical variables like horsepower and price, and visualizing distributions and relationships using charts such as histograms, scatter plots, and correlation heatmaps. By doing so, we seek to provide valuable insights that help understand the dynamics of car pricing in the automotive industry.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# ***To analyze the factors influencing car prices in the market.***

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
from numpy import math
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import rcParams
from matplotlib.ticker import FuncFormatter
import matplotlib.ticker as ticker
import seaborn as sns
from datetime import datetime
from datetime import time
# Out:
# <ipython-input-104-56e153736493>:3: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   from numpy import math

# %% [markdown]
# ### Dataset Loading

# %%
# Importing the dataset
path='/content/drive/MyDrive/Data set/automobile_data .csv'
dataset=pd.read_csv(path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First
dataset.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns
dataset.shape
# Out:
# (205, 26)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(dataset[dataset.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(dataset.isnull().sum())
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(dataset.isnull(),cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset given is a dataset about automobiles that contains most of the automobile's features. It has 205 rows and 26 columns of dataset we have.
#
# There are no missing or null values exist in the dataset. But, there are some column variables in which it contains string '?'.
#
# And, also there are some column variables that should be of numerical('int64', 'float64') datatype instead of 'object' datatype.
#
# Also, there exist outliers in some numerical columns.
#
# So, here objective is 'To analyze the factors influencing car prices in the market.'

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
dataset.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
# Dataset Describe
dataset.describe(include='all')
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   205.000000               205     205       205        205
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                41      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           205        205          205             205  205.000000  ...
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# *   **symboling**: Represents the insurance risk
#     rating of the car (-3 to +3).
#
# *   **normalized-losses**: Represents the average loss payment per insured vehicle year.
#
# *  **make**: The manufacturer or brand of the car.
#
# *   **fuel-type**: The type of fuel the car uses (e.g., diesel, gas).
#
# *   **aspiration**: The method by which air is delivered to the engine (e.g., standard, turbo).
#
# *   **num-of-doors**: The number of doors on the car (e.g., two, four).
# *   **body-style**: The body style of the car (e.g., sedan, hatchback).
#
# *   **drive-wheels**: The type of drive wheels (e.g., front-wheel drive, rear-wheel drive).
#
# *   **engine-location**: The location of the engine in the car (e.g., front, rear).
#
# *   **wheel-base**: The distance between the centers of the front and rear wheels.
#
# *   **length**: The length of the car.
# *   **width**: The width of the car.
#
# *   **height**: The height of the car.
# *   **curb-weight**: The weight of the car without passengers or cargo.
#
# *   **engine-type**: The type of engine (e.g., dohc, ohcv).
#
# *   **num-of-cylinders**: The number of cylinders in the engine (e.g., four, six).
# *  **engine-size**: The size of the engine in cubic centimeters (cc).
#
#
# *   **fuel-system**: The type of fuel system (e.g., mpfi, 2bbl).
#
# *   **bore**: The diameter of each cylinder in the engine.
#
# *   **stroke**: The distance the piston travels in each cycle.
#
# *   **compression-ratio**: The ratio of the maximum to minimum volume in the engine's combustion chamber.
# *   **horsepower**: The power generated by the engine.
#
#
# *   **peak-rpm**: The maximum revolutions per minute of the engine.
#
#
# *   **city-mpg**: The miles per gallon (MPG) in city driving conditions.
#
#
# *   **highway-mpg**: The miles per gallon (MPG) in highway driving conditions.
# *   **price**: The price of the car (target variable for analysis).

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in list(dataset.columns):
  print(f'No. of unique values in {i} is {dataset[i].nunique()}.')
# Out:
# No. of unique values in symboling is 6.
# No. of unique values in normalized-losses is 52.
# No. of unique values in make is 22.
# No. of unique values in fuel-type is 2.
# No. of unique values in aspiration is 2.
# No. of unique values in num-of-doors is 3.
# No. of unique values in body-style is 5.
# No. of unique values in drive-wheels is 3.
# No. of unique values in engine-location is 2.
# No. of unique values in wheel-base is 53.
# No. of unique values in length is 75.
# No. of unique values in width is 44.
# No. of unique values in height is 49.
# No. of unique values in curb-weight is 171.
# No. of unique values in engine-type is 7.
# No. of unique values in num-of-cylinders is 7.
# No. of unique values in engine-size is 44.
# No. of unique values in fuel-system is 8.
# No. of unique values in bore is 39.
# No. of unique values in stroke is 37.
# No. of unique values in compression-ratio is 32.
# No. of unique values in horsepower is 60.
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Create a copy of the current dataset and assigning to df
df=dataset.copy()

# Replace all column values '?' with NaN.
df=df.replace('?',np.NaN)

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
# After replacing '?' with NaN, there are some null values exist in new dataset 'df'.
# Missing/ Null values count
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# Visualizing the missing/null values after replacing '?' with NaN
sns.heatmap(df.isnull(),cbar=False)
# Out:
# <Axes: >

# %%
# convert column variables 'object' datatype to 'float64' datatype
df['price']=df['price'].astype('float64')
df['horsepower']=df['horsepower'].astype('float64')
df['normalized-losses']=df['normalized-losses'].astype('float64')

# %%
# # Identify outliers in each numeric column variable using box plot
plt.figure(figsize=(14, 10))
numerical_columns = df.select_dtypes(include=[np.number]).columns

# Iterate over numerical columns and create boxplots
for i, column in enumerate(numerical_columns, 1):
    ax = plt.subplot(5, 5, i)
    sns.boxplot(y=df[column], orient='v', width=0.5, ax=ax)
    ax.set_ylabel(column, fontsize=12)  # Set ylabel on the Axes object (ax)

plt.tight_layout()
plt.show()

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower           float64
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
# Drop missing/null values from dataset df
df= df.dropna()

# %%
# check columns datatype
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower           float64
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
# # Convert column variables 'float64' datatype to 'int64' datatype

df['horsepower']=df['horsepower'].astype('int64')
df['normalized-losses']=df['normalized-losses'].astype('int64')

# %%
# check whether datatypes changed for above column variables or not
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower             int64
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
# Check maximum price for each car brand
max_price=df.groupby(['make'])['price'].max()
print(max_price)
# Out:
# make
# audi             23875.0
# bmw              21105.0
# chevrolet         6575.0
# dodge            12964.0
# honda            12945.0
# jaguar           32250.0
# mazda            18280.0
# mercedes-benz    35056.0
# mitsubishi        9959.0
# nissan           19699.0
# peugot           18150.0
# plymouth          8921.0
# porsche          22018.0
# saab             18620.0
# subaru           11694.0
# toyota           17669.0
# volkswagen        9995.0
# volvo            22625.0
# Name: price, dtype: float64

# %%
# check average price for each car brand
average_price=df.groupby(['make'])['price'].mean().round(2)
print(average_price)
# Out:
# make
# audi             18246.25
# bmw              18857.50
# chevrolet         6007.00
# dodge             7790.12
# honda             8184.69
# jaguar           32250.00
# mazda             9080.00
# mercedes-benz    29726.40
# mitsubishi        7813.00
# nissan           10415.67
# peugot           15758.57
# plymouth          7163.33
# porsche          22018.00
# saab             15223.33
# subaru            8541.25
# toyota            9696.65
# volkswagen        8738.12
# volvo            18063.18
# Name: price, dtype: float64

# %%
# calulate average price for each unique car body style
car_body_style_avg_price= df.groupby(['body-style'])['price'].mean().round(2).sort_values(ascending= False)
print(car_body_style_avg_price)
# Out:
# body-style
# convertible    26362.50
# hardtop        13142.40
# sedan          12558.62
# wagon          11351.41
# hatchback       9220.16
# Name: price, dtype: float64

# %%
# convert 'car_body_style_avg_price' in a dataframe
car_body_style_avg_price_df= pd.DataFrame(car_body_style_avg_price).reset_index()
car_body_style_avg_price_df.columns=['body-style','avg_price']
print(car_body_style_avg_price_df)
# Out:
#     body-style  avg_price
# 0  convertible   26362.50
# 1      hardtop   13142.40
# 2        sedan   12558.62
# 3        wagon   11351.41
# 4    hatchback    9220.16

# %%
# Calculate correlation coefficient
# Correlation between City MPG and Price
correlation_city = df['city-mpg'].corr(df['price'])
print(f"Correlation between City MPG and Price: {correlation_city}")
# Out:
# Correlation between City MPG and Price: -0.69227306190206

# %%
# Calculate correlation coefficient
# Correlation between Highway MPG and Price
correlation_highway = df['highway-mpg'].corr(df['price'])
print(f"Correlation between Highway MPG and Price: {correlation_highway}")
# Out:
# Correlation between Highway MPG and Price: -0.720090097931862

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Here are some manipulations which have been done :-**
#
# * Initially, there are no missing or null values exist in the
#   original dataset.
#
# *  Firstly, I have created a copy of the current dataset and
#   assigning to df i.e. df=dataset.copy().
#
# *  Then there exists string value '?' that's why I have
#    replaced string value '?' with np.NaN.
#
# *  Then, after replacing string '?' with NaN ,there exists some
#   null values in the new dataset df.
#
#   Here, you can visualize the missing/null values :-
#
#   ![image.png](data:image/png;base64,...)
#
#
#
# *   Converted some column variables 'object' datatype to 'float64'
#   datatype to identify the outliers in each numeric column variable using box plot :-
#
#   ![image.png](data:image/png;base64,...)
#
#
# *   Dropped missing/null values from dataset df: df= df.dropna()
#
# *   Again, converted some column variables datatype 'float64' to
#    'int64' datatype which earlier you have converted into 'float64' datatype to identify outliers.
#
# *  If you have outliers in any numeric column variable, then you
#    can fill null values with the median of that column. But, here you are dropping null values instead of filling with the median value.
#
#
# *   Checked maximum price for each car brand.
#
# *   Checked average price for each car brand.
#
# *   Calculated average price for each unique car body style.
#
# *   Converted 'car_body_style_avg_price' in a dataframe.
#
#
# *   Calculated correlation coefficients:
#
#       1. Correlation between City MPG and Price
#
#       2. Correlation between Highway MPG and Price

# %% [markdown]
# ## ***4. Data Visualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1-Average Price by Car Make

# %%
average_price=df.groupby(['make'])['price'].mean().round(2).sort_values(ascending= False)
average_price_df= pd.DataFrame(average_price).reset_index()
average_price_df.columns=['make','avg_price']
print(average_price_df)
# Out:
#              make  avg_price
# 0          jaguar   32250.00
# 1   mercedes-benz   29726.40
# 2         porsche   22018.00
# 3             bmw   18857.50
# 4            audi   18246.25
# 5           volvo   18063.18
# 6          peugot   15758.57
# 7            saab   15223.33
# 8          nissan   10415.67
# 9          toyota    9696.65
# 10          mazda    9080.00
# 11     volkswagen    8738.12
# 12         subaru    8541.25
# 13          honda    8184.69
# 14     mitsubishi    7813.00
# 15          dodge    7790.12
# 16       plymouth    7163.33
# 17      chevrolet    6007.00

# %%
# Chart -1 visualization code
# Bar Plot of Average Price by Car Make
sns.set_style("whitegrid")

# Create the bar plot
plt.figure(figsize=(14, 8))
bar_plot = sns.barplot(data=average_price_df, x='make', y='avg_price', palette='viridis')

# Set title and labels
bar_plot.set_title('Average Price by Car Make', fontsize=16)
bar_plot.set_xlabel('Car Make', fontsize=14)
bar_plot.set_ylabel('Average Price', fontsize=14)

# Add value annotations slightly downward inside the top of the bars
for p in bar_plot.patches:
    # Get the height of the bar (avg_price)
    height = p.get_height()
    # Position for the annotation
    x_pos = p.get_x() + p.get_width() / 2
    y_pos = height * 0.95
    # Add text annotation
    bar_plot.text(x_pos, y_pos, f'{height * 1e-3:.2f}K',  # Adjusted to thousands
                  ha='center', va='center', fontsize=10, color='white')

# # Adjust y-axis ticks to display in thousands
bar_plot.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x * 1e-3:.1f}K'))

# Adjust x-axis labels for readability
bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=45, ha='right')

# Create custom handles and labels for the legend
palette = sns.color_palette('viridis', len(average_price_df))
handles = [plt.Line2D([0], [0], color=palette[i], lw=4) for i in range(len(average_price_df))]
labels = average_price_df['make'].tolist()  # Extract car brand in the order of appearance


# Add a legend with reversed labels
plt.legend(handles, labels, title='Car Make', title_fontsize='13', fontsize='9', bbox_to_anchor=(1.02, 1), loc='upper left')

# Adjust layout to fit elements properly
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-133-21b152b3114f>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(data=average_price_df, x='make', y='avg_price', palette='viridis')
# <ipython-input-133-21b152b3114f>:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=45, ha='right')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is a type of graph that uses bars to represent categorical data. It's commonly used to compare the values of different categories or groups.
#
# Also, this helps us understand which brands are generally more expensive or more affordable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Price Variation**: It compares average prices across different car manufacturers. This helps in identifying brands with higher or lower average prices.
#
# **Market Preferences**: Reflects consumer preferences for different car brands based on price. Brands with higher average prices may appeal to consumers looking for more specific or advanced features, while lower-priced brands may attract budget-conscious buyers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from analyzing average car prices by brand will definitely create a positive business impact.
#
# Through this, companies can identify consumer preferences in a better way for different car brands based on their prices.

# %% [markdown]
# #### Chart - 2- Relationship between normalized losses and car prices.

# %%
# Chart - 2 visualization code
# Scatter plot of normalized losses vs price
# Create figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

# Scatter plot
scatter=plt.scatter(df['normalized-losses'], df['price'],c=df['normalized-losses'], cmap='viridis', s=50 , marker='o', alpha=0.7)

# Set title, x-axis label, and y-axis label using ax methods
ax.set_title('Normalized Losses vs. Price', fontsize= 14,color='black')
ax.set_xlabel('Normalized Losses', fontsize= 12,color='black')
ax.set_ylabel('Price', fontsize= 12,color='black')

# Customize x-axis ticks
ax.set_xticks(np.arange(0, 257, 30))
plt.grid(True)

# Add color bar as a legend
cbar = fig.colorbar(scatter, ax=ax, pad=0.1)
cbar.set_label('Normalized Losses')

# Adjust ticks on the color bar
min_val = df['normalized-losses'].min()
max_val = df['normalized-losses'].max()
mid_val = 100

# Generate ticks array
ticks = np.linspace(min_val, max_val, num=3)
ticks = np.append(ticks, mid_val)  # Add 100 to the ticks array

cbar.set_ticks(ticks)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is a type of graph that displays the relationship between two numerical variables.
#
# And, here we have also two numerical column variables to visualize the relationship between these two.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here, it shows the relationship between normalized losses and car prices.
#
# **Normalized losses** defined as Average loss payment(amount paid for insurance claims against baseline) per insured vehicle per year.
#
# **It has a standard value(baseline value) of 100.**
#
# **Values Above 100**: If a vehicle's normalized-losses are above 100, it indicates that the average loss payment for that vehicle model is higher than the baseline average. It means vehicle may be associated with higher insurance costs due to factors like repair costs, accident frequency, or theft rates.
#
# **Values Below 100**: if normalized-losses are below 100, it means vehicle has lower average loss than baseline average.It means vehicle may be associated with lower insurance costs due to factors such as  lower repair costs, or lower accident rates .
#
# **Let's take an example**:-
#
# Calculation for Honda brand:
#
#
# *  Normalized-losses = 110
# *  Difference from baseline = 110 - 100 = 10
#
# * Percentage difference = (10 / 100) * 100% = 10%
#
#   So, Honda has normalized-losses 10% above the baseline.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the scatter plot of normalized losses vs. price will definitely create a positive business impact.
#
#  Companies can adjust prices based on whether a vehicle's normalized losses are above or below 100. Vehicles with lower normalized losses (**below 100**) can be priced higher, reflecting lower expected insurance costs and potentially increasing profit margins.
#
#  Conversely, vehicles with higher normalized losses (**above 100**) might be priced competitively to account for higher insurance risks, attracting customers looking for more comprehensive insurance coverage.

# %% [markdown]
# #### Chart - 3- Symboling (Insurance Risk Rating) vs Price

# %%
# Chart - 3 visualization code
# Boxplot of price distribution by symboling
fig, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x='symboling', y='price',data=df)

# Set title, x-axis label, and y-axis label using ax methods
ax.set_title('Price Distribution by Symboling',fontsize= 14, color='black')
ax.set_xlabel('Symboling',fontsize= 12, color='black')
ax.set_ylabel('Price',fontsize= 12, color='black')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, Boxplot is a suitable and effective visualization method for exploring and comparing the distribution of prices across different symboling categories in your dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This boxplot visualization shows how car prices vary across different symboling ratings.
#
# **Symboling** is a measure of risk assigned by insurance companies, with higher values indicating higher risk.
#
#  It is used as a rating system by insurance companies to assess the risk level of a car model. Symboling typically ranges from -3 to +3 .
#
#
# **•  Negative values (e.g., -3, -2, -1)**: These indicate that the
#    vehicle is less risky to insure, usually due to factors such as safety features, low accident rates, or favorable statistics.
#
# **•  Zero (0)**:  in terms of insurance risk, neither particularly
#    risky nor particularly safe.
#
#
# **•  Positive values (e.g., +1, +2, +3)**: These suggest that the vehicle is more risky to insure, potentially due to factors such as higher accident rates, greater likelihood of theft, or more expensive repair costs.
#
#
# For example, if the median price **Q2(the 50th percentile )** is 15,000 dollars tells us that half of the cars in that symboling category are priced below 15,000 dollars and half are priced above.
#
#
# Similarly, if **Q3 (the 75th percentile)** of prices in a specific symboling category is 20,000 dollars, it means that 75% of the cars within that symboling category are priced at or below 20,000 dollars.
#
#
# Similarly, if **Q1 (the 25th percentile)** of prices in a specific symboling category is 10,000 dollars, it means that 25% of the cars within that symboling category are priced at or below 10,000 dollars.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the boxplot visualization of car prices by symboling ratings will definitely create a positive business impact.
#
# Companies can strategically price vehicles based on their symboling ratings.
#
# Vehicles with lower symboling ratings (indicating lower insurance risk) can be priced higher to reflect perceived safety and lower insurance costs, potentially increasing profit margins.
#
# Conversely, vehicles with higher symboling ratings but lower prices can attract price-sensitive customers looking for bargains despite higher perceived risk.

# %% [markdown]
# #### Chart - 4- Bar Plot of Fuel Type vs Average Price

# %%
# Chart - 4 visualization code
# Bar plot of average price by fuel type
plt.figure(figsize=(10, 6))
avg_price_by_fuel_type = df.groupby('fuel-type')['price'].mean().sort_values(ascending=False)

ax=avg_price_by_fuel_type.plot(kind='bar')

# Set title, x-axis label, and y-axis label using ax methods
ax.set_title('Average Price by Fuel Type',fontsize= 14, color='black')
ax.set_xlabel('Fuel Type',fontsize= 12, color='black')
ax.set_ylabel('Average Price',fontsize= 12, color='black')

plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, bar plot is an appropriate method for visualizing and comparing the average prices of cars based on different fuel types in your dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart shows variation in average price for different fuel types.
#
# **Cost Efficiency**: Diesel fuel tends to be pricier, which might influence choices towards more fuel-efficient vehicles or impact transportation costs for businesses.
#
#
# **Consumer Preferences**: Higher average prices for diesel could indicate preferences for vehicles that use diesel, possibly due to factors like mileage or performance.
#
#
# **Market Competition**: Lower-priced fuel types might attract more price-sensitive consumers or businesses, affecting competition among fuel providers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the chart will definitely create a positive business impact.
#
# Understanding consumer preferences and cost efficiencies can guide businesses in developing and promoting fuel-efficient vehicles or products
# that meet the preferences of those who like diesel vehicles.

# %% [markdown]
# #### Chart - 5- Scatter plot of Horsepower vs Price

# %%
# Chart - 5 visualization code
# Scatter plot of horsepower vs price
# Create figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

scatter=plt.scatter(df['horsepower'], df['price'],c=df['horsepower'], cmap='viridis', s=50, alpha=0.7)

# Set title, x-axis label, and y-axis label using ax methods
ax.set_title('Horsepower vs Price',fontsize= 14, color='black')
ax.set_xlabel('Horsepower',fontsize= 12, color='black')
ax.set_ylabel('Price',fontsize= 12, color='black')

# Add color bar as a legend
cbar = fig.colorbar(scatter, ax=ax, pad=0.1)
cbar.set_label('Horsepower',fontsize= 11)

# Adjust ticks on the color bar
min_val = df['horsepower'].min()
max_val = df['horsepower'].max()

# Generate ticks array
ticks = np.linspace(min_val, max_val, num=5)


cbar.set_ticks(ticks)
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, Scatter plot effectively visualizes the relationship between horsepower and price, providing a straightforward and insightful representation of how these two variables interact within your dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Positive Relationship**: Here appears to be a generally positive relationship between horsepower and price.
# In other words we can say, as horsepower increases, the price of the car tends to increase as well.
#
# **Scattered Distribution**: The data points are spread out across the plot, suggesting variability in prices for cars with similar horsepower ratings.
#
# **Outliers**: There are some outliers where cars with higher horsepower are priced lower than expected, or vice versa.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the scatter plot of horsepower vs price will definitely create a positive business impact.
#
# Despite the variability, a trend can be observed where cars with higher horsepower generally have higher prices, which can influence consumer choices and pricing strategies in the automotive market.

# %% [markdown]
# #### Chart - 6- Histogram of Price Distribution

# %%
# Chart - 6 visualization code
# Histogram of price distribution
# Create figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

sns.histplot(df['price'], kde=True,color='black')

# Set title, x-axis label, and y-axis label using ax methods
ax.set_title('Price Distribution',fontsize= 14, color='black')
ax.set_xlabel('Price',fontsize= 12, color='black')
ax.set_ylabel('Frequency',fontsize= 12, color='black')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, histogram effectively represents the distribution of prices in your dataset, providing insights into the range, frequency, and shape of the price data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Central Tendency**: The histogram indicates that most car prices in the dataset are clustered within a specific range, suggesting a common price point for the majority of cars.
#
# **Skewness**: The distribution appears slightly skewed to the right (positive skew), indicating that there are more cars with lower to moderate prices compared to higher-priced ones.
#
# **The height of the bars (frequency) at different price levels gives a visual representation of how often different price ranges occur in the dataset**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights gained from the price distribution histogram will definitely create a positive business impact.
#
# Recognizing the positive skew in the distribution helps businesses understand that there are more customers interested in lower to moderate priced cars.

# %% [markdown]
# #### Chart - 7- Bar Plot for Car Body Style Vs Average Price

# %%
print(car_body_style_avg_price_df)
# Out:
#     body-style  avg_price
# 0  convertible   26362.50
# 1      hardtop   13142.40
# 2        sedan   12558.62
# 3        wagon   11351.41
# 4    hatchback    9220.16

# %%
# Chart - 7 visualization code
# Bar Plot for Car Body Style Vs Average Price
sns.set_style("whitegrid")

# Create the bar plot
plt.figure(figsize=(12, 8))
bar_plot = sns.barplot(data=car_body_style_avg_price_df, x='avg_price',y='body-style', palette='viridis',width=0.7)

# Add title and labels
bar_plot.set_title('Car Body Style Vs Average Price', fontsize=16)
bar_plot.set_xlabel('Average Price', fontsize=14)
bar_plot.set_ylabel('Body Style', fontsize=14)

for p in bar_plot.patches:
    # Get the height of the bar (avg_price)
    height = p.get_width()

    # Convert height to thousands
    height_in_thousands = height * 1e-3

    # Calculate position for the annotation
    x_pos = height * 0.99
    y_pos = p.get_y() + p.get_height() / 2
    # Add text annotation inside the bar
    bar_plot.text(x_pos, y_pos,
                  f'{height_in_thousands:.2f}K',
                  ha='right', va='center', fontsize=10, color='white')


# # Adjust x-axis ticks to display in thousands
bar_plot.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x * 1e-3:.1f}K'))

# Rotate x-tick labels if necessary
bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=0)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-140-95a7210c75ed>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(data=car_body_style_avg_price_df, x='avg_price',y='body-style', palette='viridis',width=0.7)
# <ipython-input-140-95a7210c75ed>:34: UserWarning: FixedFormatter should only be used together with FixedLocator
#   bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, Bar plot chosen effectively communicates the relationship between car body styles and their average prices, making it a suitable and effective choice for visualizing this type of data comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Price Variation by Body Style**: The bar plot visually represents how average prices vary across different car body styles.
#
# **Popular Body Styles**: It shows which car body styles are more demanding or often chosen by consumers in comparison to their prices.
#
# **Consumer Preferences**: The visualization helps identify consumer preferences based on body style i.e. which car body styles people prefer more, and which ones they think are worth more money in terms of pricing.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the bar plot comparing car body styles to their average prices will definitely create a positive business impact.
#
# Understanding how average prices vary across different body styles allows businesses to set competitive pricing that aligns with consumer expectations. This can attract more customers and increase sales.

# %% [markdown]
# #### Chart - 8- Scatter plot for city MPG vs price

# %%
# Chart - 8 visualization code
# Scatter plot for city MPG vs price
# Create figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

scatter=plt.scatter(df['city-mpg'], df['price'],c=df['city-mpg'], cmap='viridis', s=50, alpha=0.7)
ax.set_title('City MPG vs Price',fontsize= 14, color='black')
ax.set_xlabel('City MPG',fontsize= 12, color='black')
ax.set_ylabel('Price',fontsize= 12, color='black')


# Add color bar as a legend
cbar = fig.colorbar(scatter, ax=ax, pad=0.1)
cbar.set_label('City MPG',fontsize= 11)

# Adjust ticks on the color bar
min_val = df['city-mpg'].min()
max_val = df['city-mpg'].max()

# Generate ticks array
ticks = np.linspace(min_val, max_val, num=3)


cbar.set_ticks(ticks)
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, Scatter plot chosen effectively visualizes how city MPG and prices are related, providing a clear and insightful representation of their distribution and any potential trends or outliers within the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Inverse Relationship**: The scatter plot shows an inverse relationship between city MPG and price
#
# **Price Range**: The spread of points across the plot indicates the range of prices for cars with different city MPG ratings. Lower MPG cars are scattered towards higher price points, while higher MPG cars are generally clustered towards lower prices.
#
# **Decision Making**: Consumers looking for cost savings on fuel may prefer cars with higher city MPG at lower prices. On the other hand, those prioritizing other features or performance may accept lower MPG at higher prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the scatter plot of city MPG vs price will definitely create a positive business impact.
#
# Vehicles with higher city MPG often use simpler or more established technologies that are less costly to manufacture due to this price will be less for higher city MPG vehicles.
#
# Recognizing how city MPG affects pricing enables businesses to strategically price their vehicles. They can offer fuel-efficient cars with higher MPG at attractive prices, appealing to budget-conscious consumers who prioritize saving on fuel.

# %% [markdown]
# #### Chart - 9- Scatter plot for highway MPG vs price

# %%
# Chart - 9 visualization code
# Scatter plot for highway MPG vs price
# Create figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

scatter=plt.scatter(df['highway-mpg'], df['price'],c=df['highway-mpg'], cmap='viridis', s=50, alpha=0.7)
ax.set_title('Highway MPG vs Price',fontsize=14,color='black')
ax.set_xlabel('Highway MPG',fontsize= 12, color='black')
ax.set_ylabel('Price',fontsize= 12, color='black')
plt.grid(True)

# Add color bar as a legend
cbar = fig.colorbar(scatter, ax=ax, pad=0.1)
cbar.set_label('Highway MPG',fontsize= 11)

# Adjust ticks on the color bar
min_val = df['highway-mpg'].min()
max_val = df['highway-mpg'].max()

# Generate ticks array
ticks = np.linspace(min_val, max_val, num=5)


cbar.set_ticks(ticks)
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, Scatter plot chosen effectively visualizes how highway MPG and prices are related, providing a straightforward and insightful representation of their distribution and any potential trends or outliers within the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Inverse Relationship**: Similar to city MPG, there is an inverse relationship between highway MPG and price. Cars with higher highway MPG tend to have lower prices, indicating that fuel-efficient cars are generally priced more attractively.
#
# **Price Range**: The spread of points across the plot shows the range of prices for cars with different highway MPG ratings. Cars with lower highway MPG are scattered towards higher price points, while those with higher highway MPG are clustered towards lower prices.
#
# **Consumer Decision Making**: The plot suggests that consumers are willing to pay more for vehicles with lower highway MPG if they prioritize other factors such as performance, brand, or features over fuel efficiency.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the scatter plot of highway MPG vs price will definitely create a positive business impact.
#
# Vehicles with higher highway MPG often use simpler or more established technologies that are less costly to manufacture due to this price will be less for higher highway MPG vehicles.
#
# Understanding how higher highway MPG influences pricing allows businesses to strategically set prices for their vehicles. They can offer fuel-efficient cars with superior highway MPG at competitive rates, attracting consumers who prioritize fuel savings.

# %% [markdown]
# #### Chart - 10- 3D Scatter Plot: Horsepower vs. MPG

# %%
# Chart - 10 visualization code
# 3D Scatter Plot: Horsepower vs. MPG

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
scatter = ax.scatter(df['horsepower'], df['city-mpg'], df['highway-mpg'], c=df['horsepower'], cmap='viridis', s=50)

ax.set_title('3D Scatter Plot: Horsepower vs. MPG',fontsize=14,color='black')
ax.set_xlabel('Horsepower',fontsize=12,color='black')
ax.set_ylabel('City MPG',fontsize=12,color='black')
ax.set_zlabel('Highway MPG',fontsize=12,color='black')

# Color bar as a legend
cbar = fig.colorbar(scatter, ax=ax, pad=0.1)
cbar.set_label('Horsepower',fontsize=11)
cbar.set_ticks(np.linspace(df['horsepower'].min(), df['horsepower'].max(), num=5))

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A 3D chart allows you to plot and visualize the relationship between three variables in a single plot.
#
# This is particularly useful when exploring interactions and dependencies between multiple factors simultaneously.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Correlation Patterns**: The plot visually shows how 'Horsepower' relates to both 'City MPG' (City Miles Per Gallon) and 'Highway MPG' (Highway Miles Per Gallon).
#
# Through this plot, we can observe that vehicles with higher horsepower tend to have lower fuel efficiency (lower MPG) in both city and highway driving conditions.
#
# Here, we can also observe that vehicles with lower horsepower will have higher fuel efficiency (higher MPG) in both city and highway driving conditions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes, the insights gained from 3D scatter plot of Horsepower vs. MPG will definitely create a positive business impact.
#
# Understanding these insights, we can say that vehicles with higher fuel efficiency (higher MPG)
# will have lower prices due to low manufacturing costs which will lead to an increase in profit margin.

# %% [markdown]
# #### Chart - 11- Correlation Heatmap of Numerical Variables

# %%
# Chart - 11 visualization code
# Correlation Heatmap of Numerical Variables
corr_df= df[['symboling','normalized-losses', 'engine-size', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']]
corr = corr_df.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cbar=True, fmt='.2f', linewidths=.5)
plt.title('Correlation Heatmap of Numerical Variables',fontsize=14,color='black')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, Correlation Heatmap chosen effectively visualizes the relationships between numerical variables in your dataset, providing valuable insights into how these variables correlate with each other.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows how strongly each pair of numerical variables is correlated with one another.
#
# **Positive and Negative Correlations**: Positive correlations (values closer to 1) indicate that as one variable increases, the other tends to increase as well. Negative correlations (values closer to -1) indicate that as one variable increases, the other tends to decrease.
#
# **Key Correlations**:
#
# **Engine Size and Horsepower**: These variables often show a strong positive correlation, meaning larger engines typically have higher horsepower.
#
# **City MPG and Highway MPG**: These variables may show a strong positive correlation, indicating that cars with higher city MPG also tend to have higher highway MPG.
#
# **Price and Engine Size/Horsepower**: There might be a positive correlation between price and engine size/horsepower, indicating that more powerful or larger-engine cars tend to be more expensive.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the correlation heatmap of numerical variables will definitely create a positive business impact.
#
# Understanding the positive correlation between price and engine size/horsepower allows businesses to justify pricing for more powerful or larger-engine cars. They can confidently set higher prices for these models, appealing to consumers willing to pay for enhanced performance.
#
# Recognizing the positive correlation between city MPG and highway MPG guides businesses in promoting fuel-efficient vehicles.
# They can emphasize the benefits of higher MPG ratings to attract environmentally conscious consumers and those seeking cost savings on fuel.

# %% [markdown]
# #### Chart - 12- Pair Plot visualization

# %%
# Chart - 12 visualization code
# Pair Plot visualization code
sns.pairplot(df[['symboling','normalized-losses','wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-size', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']])
plt.suptitle('Pairplot of Numerical Variables vs Price',fontsize=28, y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, Pair plot is a powerful way to explore how different numerical factors in your dataset relate to each other and to the prices of cars. It's like having multiple scatter plots all together, which helps you quickly spot connections between things like car size, engine power, and their prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Scatter plots** reveal relationships between price and other variables such as engine size, horsepower, and MPG ratings.
#
# It provides a visual examination of how combinations of variables (e.g., engine size vs. price, curb weight vs. price) relate to each other and to price.
#
# Patterns such as clusters or trends in the scatter plots indicate how changes in one variable impact the price of cars. For example, higher engine size or horsepower tends to correlate with higher prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the pair plot visualization of numerical variables against price will definitely create a positive business impact.
#
# The pair plot visualization provides a comprehensive view of the relationships between numerical variables and price in the dataset.
#
# It aids in understanding the factors influencing car prices and can inform strategic decisions related to pricing, marketing, and product development in the automotive industry.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# **Solutions to achieve business objective:-**
#
# *  **Explore Price Variability by Car Make**:
#    companies can identify consumer preferences in a better way for different car brands based on their prices.
#
#    Brands with higher average prices may appeal to consumers looking for more specific or advanced features, while lower-priced brands may attract budget-conscious buyers.
#
# *   **Assess Impact of Normalized Losses**:
#    Companies can adjust prices based on whether a vehicle's normalized losses are above or below 100.
#
#    Vehicles with lower normalized losses (below 100) can be priced higher, reflecting lower expected insurance costs and potentially increasing profit margins.
#
#
# *   **Understand Insurance Risk Rating
#      Influence**: Companies can strategically price vehicles based on their symboling ratings.
#
#      Vehicles with lower symboling ratings (indicating lower insurance risk) can be priced higher to reflect perceived safety and lower insurance costs, potentially increasing profit margins.
#
#
# *   **Fuel Type Analysis**: Understanding
#    consumer preferences and cost efficiencies can guide businesses in developing and promoting fuel-efficient vehicles or products that meet the preferences of those who like diesel vehicles.
#
# *   **Engine Power Impact**: Despite the
#    variability, a trend can be observed where cars with higher horsepower generally have higher prices, which can influence consumer choices and pricing strategies in the automotive market.
#
# *   **Price Distribution Overview**: Recognizing the positive skew
#      in the distribution helps businesses understand that there are more customers interested in lower to moderate priced cars.
#
# *   **Body Style Comparison**: Understanding how
#    average prices vary across different body styles allows businesses to set competitive pricing that aligns with consumer expectations. This can attract more customers and increase sales.
#
# *   **Fuel Efficiency Impact**: Understanding
#    the insights, we can say that vehicles with higher fuel efficiency (higher MPG) will have lower prices due to low manufacturing costs which will lead to an increase in profit margin.
#
# *  **Identify Strong Relationships**:
#    Understanding the positive correlation between price and engine size/horsepower allows businesses to justify pricing for more powerful or larger-engine cars.
#
#    They can confidently set higher prices for these models, appealing to consumers willing to pay for enhanced performance.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
#
# ***Here are some conclusions:-***
#
# *   **Brand Impact**: Some car brands consistently command higher
#      prices, indicating strong brand perception and market demand.
#
# *   **Safety and Pricing**: Cars with lower insurance risk ratings
#      (symboling) generally have higher prices, reflecting consumer preferences for safer vehicles.
#
# *   **Engine Power**: There is a clear trend where cars with
#       higher horsepower tend to cost more, highlighting the importance of performance in pricing.
#
# *   **Fuel Type Influence**: Diesel cars often come with higher
#       price tags compared to gasoline cars, influenced by factors like fuel efficiency and market demand.
#
# *   **Body Style Preferences**: Different car body styles affect
#       prices differently, catering to diverse consumer preferences for style and functionality.
#
#
# *   **Fuel Efficiency**: Cars with better city and highway MPG
#       ratings generally have higher prices, indicating consumer willingness to pay more for fuel-efficient vehicles.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
